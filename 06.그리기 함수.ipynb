# %%
import numpy as np
import sys
import cv2
import matplotlib.pylab as plt
# !pip install opencv-python

# %% [markdown]
# OpenCV 그리기 함수
# - OpenCV에서는 영상에 선, 도형, 문자열을 출력하는 그리기 함수를 제공합니다.
# - 선 그리기 : 직선, 화살표, 마커 등
# - 도형 그리기 :  사각형, 원, 타원, 다각형 등
# - 문자열 출력
#
# 그리기 함수 사용시 주의할 점
# - 그리기 알고리즘을 이용하여 영상의 픽셀 값 자체를 변경합니다. 따라서 원본 영상이 필요하면 복사본을 만들어서 그리고 출력하는 방식으로 사용합니다.
# - 그레이스케일 영상에서는 컬러로 그릴 수 없습니다.  cv2.cvtColor() 함수로 BGR 컬러 영상으로 변환한 후에 그리기 함수를 호출하는 방법이 있습니다.

# %%
img=np.full((400,400,3),255,np.uint8)

# %%
cv2.line(img, (50, 50), (200, 50), (0, 0, 255), 5)
cv2.rectangle(img, (50, 200, 150, 100), (0, 255, 0), 2)
cv2.rectangle(img, (70, 220), (180, 280), (0, 128, 0), -1)
cv2.circle(img, (300, 100), 30, (255, 255, 0), -1, cv2.LINE_AA)
cv2.circle(img, (300, 100), 60, (255, 0, 0), 3, cv2.LINE_AA)

pts = np.array([[250, 200], [300, 200], [350, 300], [250, 300]])
cv2.polylines(img, [pts], True, (255, 0, 255), 2)

text = 'Hello? OpenCV ' + cv2.__version__
cv2.putText(img, text, (50, 350), cv2.FONT_HERSHEY_SIMPLEX, 0.8, 
            (0, 0, 255), 1, cv2.LINE_AA)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.axis('off')
plt.imshow(img)

#cv2.imshow('image',img)
#cv2.waitKey()
#cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
