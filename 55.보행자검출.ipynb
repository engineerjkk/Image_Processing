# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random


# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\rkdwn\anaconda3\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\rkdwn\anaconda3\lib\site-packages (from opencv-python) (1.20.1)

# %%
cap = cv2.VideoCapture('vtest.avi')


if not cap.isOpened():

    print('Video open failed!')

    sys.exit()

# %%
hog = cv2.HOGDescriptor()

# %%
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# %%
while True:

    ret, frame = cap.read()


    if not ret:

        break


    # 매 프레임마다 보행자 검출

    detected, _ = hog.detectMultiScale(frame)

    #매 프레임마다 detectMultiScale 함수호출해서 사각형 정보 받아옴, weight는 가져오지 않음

    # 검출 결과 화면 표시

    for (x, y, w, h) in detected:

        c = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

        #사각형을 랜덤한 색깔로 찾아준다.

        cv2.rectangle(frame, (x, y, w, h), c, 3)

    #plt.axis('off'),plt.imshow(frame)
    cv2.imshow('frame', frame)

    if cv2.waitKey(10) == 27:

        break
    
    cv2.destroyAllWindows()
